# %%
import pandas as pd
df=pd.read_csv("airbnb_col_data.csv")

# %%
df
# Out:
#              id                           listing_url  \
# 0       1003530  https://www.airbnb.com/rooms/1003530
# 1       1003530  https://www.airbnb.com/rooms/1003530
# 2       1003530  https://www.airbnb.com/rooms/1003530
# 3       1003530  https://www.airbnb.com/rooms/1003530
# 4       1003530  https://www.airbnb.com/rooms/1003530
# ...         ...                                   ...
# 151419  9887054  https://www.airbnb.com/rooms/9887054
# 151420  9887054  https://www.airbnb.com/rooms/9887054
# 151421  9887054  https://www.airbnb.com/rooms/9887054
# 151422  9907907  https://www.airbnb.com/rooms/9907907
# 151423  9936016  https://www.airbnb.com/rooms/9936016
#
#                                        name  \
# 0       New York City - Upper West Side Apt
# 1       New York City - Upper West Side Apt
# 2       New York City - Upper West Side Apt
# 3       New York City - Upper West Side Apt
# 4       New York City - Upper West Side Apt
# ...

# %%
df.shape
# Out:
# (151424, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151424 entries, 0 to 151423
# Data columns (total 35 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   151424 non-null  int64
#  1   listing_url          151424 non-null  object
#  2   name                 151403 non-null  object
#  3   description          151273 non-null  object
#  4   street               151424 non-null  object
#  5   government_area      151424 non-null  object
#  6   country              151424 non-null  object
#  7   country_code         151424 non-null  object
#  8   coordinates          151424 non-null  object
#  9   price                151424 non-null  int64
#  10  security_deposit     151424 non-null  int64
#  11  cleaning_fee         151424 non-null  int64
#  12  cancellation_policy  151424 non-null  object
#  13  property_type        151424 non-null  object
#  14  room_type            151424 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'name', 'description', 'street', 'government_area',
#        'country', 'country_code', 'coordinates', 'price', 'security_deposit',
#        'cleaning_fee', 'cancellation_policy', 'property_type', 'room_type',
#        'bed_type', 'minimum_nights', 'maximum_nights', 'accommodates',
#        'bedrooms', 'beds', 'bathrooms', 'amenities', 'guests_included',
#        'availability_365', 'host_id', 'host_name', 'number_of_reviews',
#        'overall_score', 'cleanliness_score', 'checkin_score',
#        'communication_score', 'location_score', 'value_score', 'rating'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# id                       0
# listing_url              0
# name                    21
# description            151
# street                   0
# government_area          0
# country                  0
# country_code             0
# coordinates              0
# price                    0
# security_deposit         0
# cleaning_fee             0
# cancellation_policy      0
# property_type            0
# room_type                0
# bed_type                 0
# minimum_nights           0
# maximum_nights           0
# accommodates             0
# bedrooms                 0
# beds                     0
# bathrooms                0
# amenities              276
# guests_included          0
# availability_365         0
# host_id                  0
# host_name                0
# number_of_reviews        0
# overall_score            0
# cleanliness_score        0
# checkin_score            0
# communication_score      0
# location_score           0
# value_score              0
# ...

# %%
emp=df.applymap(lambda x: x == '')
# Out:
# C:\Users\siva Bharathi\AppData\Local\Temp\ipykernel_3356\3518953996.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   emp=df.applymap(lambda x: x == '')

# %%
emp.sum()
# Out:
# id                     0
# listing_url            0
# name                   0
# description            0
# street                 0
# government_area        0
# country                0
# country_code           0
# coordinates            0
# price                  0
# security_deposit       0
# cleaning_fee           0
# cancellation_policy    0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# accommodates           0
# bedrooms               0
# beds                   0
# bathrooms              0
# amenities              0
# guests_included        0
# availability_365       0
# host_id                0
# host_name              0
# number_of_reviews      0
# overall_score          0
# cleanliness_score      0
# checkin_score          0
# communication_score    0
# location_score         0
# value_score            0
# rating                 0
# dtype: int64

# %%
df.dropna(how='any',subset='name',inplace=True)

# %%
df['description'].fillna(value='No Description Provided', inplace=True)
df['amenities'].fillna(value='Not Available',inplace=True)

# %%
df.isna().sum()
# Out:
# id                     0
# listing_url            0
# name                   0
# description            0
# street                 0
# government_area        0
# country                0
# country_code           0
# coordinates            0
# price                  0
# security_deposit       0
# cleaning_fee           0
# cancellation_policy    0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# accommodates           0
# bedrooms               0
# beds                   0
# bathrooms              0
# amenities              0
# guests_included        0
# availability_365       0
# host_id                0
# host_name              0
# number_of_reviews      0
# overall_score          0
# cleanliness_score      0
# checkin_score          0
# communication_score    0
# location_score         0
# value_score            0
# rating                 0
# dtype: int64

# %%
df.shape
# Out:
# (151403, 35)

# %%
df[df.duplicated()]
# Out:
#              id                           listing_url  \
# 1       1003530  https://www.airbnb.com/rooms/1003530
# 2       1003530  https://www.airbnb.com/rooms/1003530
# 3       1003530  https://www.airbnb.com/rooms/1003530
# 4       1003530  https://www.airbnb.com/rooms/1003530
# 5       1003530  https://www.airbnb.com/rooms/1003530
# ...         ...                                   ...
# 151416  9993190  https://www.airbnb.com/rooms/9993190
# 151417  9993190  https://www.airbnb.com/rooms/9993190
# 151419  9887054  https://www.airbnb.com/rooms/9887054
# 151420  9887054  https://www.airbnb.com/rooms/9887054
# 151421  9887054  https://www.airbnb.com/rooms/9887054
#
#                                                      name  \
# 1                     New York City - Upper West Side Apt
# 2                     New York City - Upper West Side Apt
# 3                     New York City - Upper West Side Apt
# 4                     New York City - Upper West Side Apt
# ...

# %%
df_unique = df.drop_duplicates(subset=['id'], keep='first')

# %%
df_unique.shape
# Out:
# (5547, 35)

# %%
df_unique
# Out:
#               id                            listing_url  \
# 0        1003530   https://www.airbnb.com/rooms/1003530
# 70      10133554  https://www.airbnb.com/rooms/10133554
# 99      10059872  https://www.airbnb.com/rooms/10059872
# 102     10084023  https://www.airbnb.com/rooms/10084023
# 183     10091713  https://www.airbnb.com/rooms/10091713
# ...          ...                                    ...
# 151402   9985696   https://www.airbnb.com/rooms/9985696
# 151403   9993190   https://www.airbnb.com/rooms/9993190
# 151418   9887054   https://www.airbnb.com/rooms/9887054
# 151422   9907907   https://www.airbnb.com/rooms/9907907
# 151423   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                      name  \
# 0                     New York City - Upper West Side Apt
# 70                    Double and triple rooms Blue mosque
# 99                     Soho Cozy, Spacious and Convenient
# ...

# %%
df_unique.to_csv('airbnb_data_cleaned1.csv', index=False)
